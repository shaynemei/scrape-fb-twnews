# %%
import reuse, sys
sys.meta_path.append(reuse.NotebookFinder())

import pandas as pd
import scrapeComments
page = 'ltn'
scrapeComments.get(page)
# Out:
# importing Jupyter notebook from scrapeComments.ipynb
# init .csv successful!
# up to article 20 saved!
# up to article 40 saved!
# up to article 60 saved!
# up to article 80 saved!
# up to article 100 saved!
# up to article 120 saved!
# up to article 140 saved!
# up to article 160 saved!
# up to article 180 saved!
# up to article 200 saved!
# up to article 220 saved!
# up to article 240 saved!
# up to article 260 saved!
# up to article 280 saved!
# up to article 300 saved!
# up to article 320 saved!
# up to article 340 saved!
# up to article 360 saved!
# up to article 380 saved!
# up to article 400 saved!
# up to article 420 saved!
# up to article 440 saved!
# up to article 460 saved!
# up to article 480 saved!
# up to article 500 saved!
# up to article 520 saved!
# up to article 540 saved!
# up to article 560 saved!
# up to article 580 saved!
# up to article 600 saved!
# up to article 620 saved!
# up to article 640 saved!
# up to article 660 saved!
# up to article 680 saved!
# ...
