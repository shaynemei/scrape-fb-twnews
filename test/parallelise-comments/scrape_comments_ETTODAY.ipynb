# %%
import reuse, sys
sys.meta_path.append(reuse.NotebookFinder())

import pandas as pd
import scrapeComments
page = 'ettoday'
scrapeComments.get(page, start_idx=4261)
# Out:
# importing Jupyter notebook from scrapeComments.ipynb
# init .csv successful!
# ------------------------------------------------
# Something went WRONG saving articles 4261 to 4280.
# Empty data passed with indices specified.
# ------------------------------------------------
# up to article 4300 saved!
# ------------------------------------------------
# Something went WRONG saving articles 4301 to 4320.
# Empty data passed with indices specified.
# ------------------------------------------------
# ------------------------------------------------
# Something went WRONG saving articles 4321 to 4340.
# Empty data passed with indices specified.
# ------------------------------------------------
# ------------------------------------------------
# Something went WRONG saving articles 4341 to 4360.
# Empty data passed with indices specified.
# ------------------------------------------------
# ------------------------------------------------
# Something went WRONG saving articles 4361 to 4380.
# Empty data passed with indices specified.
# ------------------------------------------------
# ------------------------------------------------
# Something went WRONG saving articles 4381 to 4400.
# Empty data passed with indices specified.
# ------------------------------------------------
# ------------------------------------------------
# Something went WRONG saving articles 4401 to 4420.
# Empty data passed with indices specified.
# ------------------------------------------------
# ------------------------------------------------
# Something went WRONG saving articles 4421 to 4440.
# Empty data passed with indices specified.
# ------------------------------------------------
# ------------------------------------------------
# Something went WRONG saving articles 4441 to 4460.
# Empty data passed with indices specified.
# ------------------------------------------------
# ------------------------------------------------
# Something went WRONG saving articles 4461 to 4480.
# Empty data passed with indices specified.
# ------------------------------------------------
# up to article 4500 saved!
# up to article 4520 saved!
# up to article 4540 saved!
# up to article 4560 saved!
# up to article 4580 saved!
# up to article 4600 saved!
# up to article 4620 saved!
# up to article 4640 saved!
# up to article 4660 saved!
# up to article 4680 saved!
# up to article 4700 saved!
# up to article 4720 saved!
# up to article 4740 saved!
# up to article 4760 saved!
# up to article 4780 saved!
# up to article 4800 saved!
# up to article 4820 saved!
# up to article 4840 saved!
# up to article 4860 saved!
# up to article 4880 saved!
# up to article 4900 saved!
# up to article 4920 saved!
# up to article 4940 saved!
# up to article 4960 saved!
# up to article 4980 saved!
# up to article 5000 saved!
# up to article 5020 saved!
# up to article 5040 saved!
# up to article 5060 saved!
# up to article 5080 saved!
# up to article 5100 saved!
# up to article 5120 saved!
# up to article 5140 saved!
# up to article 5160 saved!
# all results saved.
